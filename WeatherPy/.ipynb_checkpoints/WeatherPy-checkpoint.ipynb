# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
cities_format = []
# Parsing through cities to remake list suitable for api query format
for city in cities:
    
    # replacing spaces in between words with '&'
    if ' ' in city:
        city = city.replace(' ', '&')
        
    # Appending to new list 
    cities_format.append(city)

# %%
# Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather?'
unit = 'metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities_format):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={unit}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta&arenas
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | estelle
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | ostrovnoy
# Processing Record 8 of Set 1 | padang
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | coahuayana
# Processing Record 11 of Set 1 | east&london
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | kiunga
# Processing Record 14 of Set 1 | cabo&san&lucas
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | corrales
# Processing Record 17 of Set 1 | cape&town
# Processing Record 18 of Set 1 | shelburne
# Processing Record 19 of Set 1 | urengoy
# Processing Record 20 of Set 1 | fortuna
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | carutapera
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | srandakan
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 1 | doctor&pedro&p.&pena
# City not found. Skipping...
# Processing Record 29 of Set 1 | seoul
# Processing Record 30 of Set 1 | nome
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | port&alfred
# Processing Record 33 of Set 1 | namatanai
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | kasongo-lunda
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | suratgarh
# Processing Record 38 of Set 1 | nelson&bay
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | slave&lake
# City not found. Skipping...
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | biltine
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | mayumba
# Processing Record 49 of Set 1 | veraval
# Processing Record 50 of Set 1 | deputatskiy
# Processing Record 0 of Set 2 | haines&junction
# Processing Record 1 of Set 2 | malumfashi
# Processing Record 2 of Set 2 | werda
# Processing Record 3 of Set 2 | wichita&falls
# Processing Record 4 of Set 2 | fredericksburg
# Processing Record 5 of Set 2 | bonavista
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | bako
# Processing Record 8 of Set 2 | suhbaatar
# Processing Record 9 of Set 2 | tefe
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | japura
# Processing Record 14 of Set 2 | new&norfolk
# Processing Record 15 of Set 2 | wairoa
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | lata
# Processing Record 19 of Set 2 | maryville
# Processing Record 20 of Set 2 | fairbanks
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | naryan-mar
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | caramay
# Processing Record 25 of Set 2 | tiarei
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | nanortalik
# Processing Record 28 of Set 2 | charagua
# Processing Record 29 of Set 2 | ulaanbaatar
# Processing Record 30 of Set 2 | dawlatabad
# Processing Record 31 of Set 2 | puerto&baquerizo&moreno
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | nouakchott
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | pec
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | ebebiyin
# Processing Record 38 of Set 2 | ixtapa
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | saint&george
# City not found. Skipping...
# Processing Record 42 of Set 2 | mirnyy
# Processing Record 43 of Set 2 | mar&del&plata
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 2 | tautira
# Processing Record 48 of Set 2 | mwingi
# Processing Record 49 of Set 2 | sarany
# Processing Record 0 of Set 3 | ponta&do&sol
# Processing Record 1 of Set 3 | geraldton
# Processing Record 2 of Set 3 | mao
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | skjervoy
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | maragogi
# Processing Record 7 of Set 3 | thinadhoo
# Processing Record 8 of Set 3 | lavrentiya
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | vanimo
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | kang
# Processing Record 15 of Set 3 | herat
# Processing Record 16 of Set 3 | valleyview
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | comodoro&rivadavia
# Processing Record 19 of Set 3 | abu&dhabi
# Processing Record 20 of Set 3 | moose&factory
# Processing Record 21 of Set 3 | presidencia&roque&saenz&pena
# City not found. Skipping...
# Processing Record 22 of Set 3 | yangambi
# Processing Record 23 of Set 3 | san&quintin
# Processing Record 24 of Set 3 | vagur
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | port&hedland
# Processing Record 27 of Set 3 | shingu
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | dubrovnik
# Processing Record 30 of Set 3 | saint&anthony
# City not found. Skipping...
# Processing Record 31 of Set 3 | saeby
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | mudgee
# Processing Record 34 of Set 3 | lagoa
# Processing Record 35 of Set 3 | ribeira&grande
# Processing Record 36 of Set 3 | vila&franca&do&campo
# Processing Record 37 of Set 3 | mount&gambier
# Processing Record 38 of Set 3 | vohma
# Processing Record 39 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | tabas
# Processing Record 42 of Set 3 | ewa&beach
# Processing Record 43 of Set 3 | arraial&do&cabo
# Processing Record 44 of Set 3 | ust-nera
# Processing Record 45 of Set 3 | xining
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | berlevag
# Processing Record 48 of Set 3 | aykhal
# Processing Record 49 of Set 3 | beamsville
# Processing Record 0 of Set 4 | codrington
# Processing Record 1 of Set 4 | vao
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | yar-sale
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | chernyshevskiy
# Processing Record 6 of Set 4 | erenhot
# Processing Record 7 of Set 4 | port&moresby
# Processing Record 8 of Set 4 | broken&hill
# City not found. Skipping...
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | bredy
# Processing Record 11 of Set 4 | krasnoarmeysk
# Processing Record 12 of Set 4 | balsas
# Processing Record 13 of Set 4 | isangel
# Processing Record 14 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 4 | pinheiro&machado
# Processing Record 16 of Set 4 | lorica
# Processing Record 17 of Set 4 | tevaitoa
# Processing Record 18 of Set 4 | la&plata
# City not found. Skipping...
# Processing Record 19 of Set 4 | kieta
# Processing Record 20 of Set 4 | san&cristobal
# Processing Record 21 of Set 4 | novyy&urengoy
# Processing Record 22 of Set 4 | lorengau
# Processing Record 23 of Set 4 | gamba
# Processing Record 24 of Set 4 | castries
# Processing Record 25 of Set 4 | amapa
# Processing Record 26 of Set 4 | pochutla
# Processing Record 27 of Set 4 | mezen
# Processing Record 28 of Set 4 | rock&sound
# Processing Record 29 of Set 4 | grand&gaube
# Processing Record 30 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 4 | abalak
# Processing Record 32 of Set 4 | bambous&virieux
# Processing Record 33 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 4 | porto&novo
# Processing Record 35 of Set 4 | burnie
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | griffith
# Processing Record 38 of Set 4 | gwembe
# Processing Record 39 of Set 4 | vila&velha
# Processing Record 40 of Set 4 | belogradcik
# City not found. Skipping...
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | san&roque
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | pangody
# Processing Record 47 of Set 4 | georgetown
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | tosu
# Processing Record 0 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 5 | sur
# Processing Record 2 of Set 5 | davila
# Processing Record 3 of Set 5 | te&anau
# City not found. Skipping...
# Processing Record 4 of Set 5 | hambantota
# Processing Record 5 of Set 5 | senno
# Processing Record 6 of Set 5 | perth
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 9 of Set 5 | manokwari
# Processing Record 10 of Set 5 | rio&grande
# Processing Record 11 of Set 5 | mamit
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 5 | botwood
# Processing Record 15 of Set 5 | phonhong
# Processing Record 16 of Set 5 | islamkot
# Processing Record 17 of Set 5 | monrovia
# Processing Record 18 of Set 5 | rapid&valley
# City not found. Skipping...
# Processing Record 19 of Set 5 | the&valley
# City not found. Skipping...
# Processing Record 20 of Set 5 | chokurdakh
# Processing Record 21 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 22 of Set 5 | keetmanshoop
# Processing Record 23 of Set 5 | taoudenni
# Processing Record 24 of Set 5 | mehamn
# Processing Record 25 of Set 5 | nioki
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | chara
# Processing Record 28 of Set 5 | grand&river&south&east
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | kushiro
# Processing Record 31 of Set 5 | santa&maria&del&oro
# Processing Record 32 of Set 5 | pandhurna
# Processing Record 33 of Set 5 | verdalsora
# City not found. Skipping...
# Processing Record 34 of Set 5 | sabha
# Processing Record 35 of Set 5 | half&moon&bay
# Processing Record 36 of Set 5 | bratsk
# Processing Record 37 of Set 5 | birjand
# Processing Record 38 of Set 5 | taormina
# Processing Record 39 of Set 5 | balikpapan
# Processing Record 40 of Set 5 | teknaf
# Processing Record 41 of Set 5 | akaltara
# Processing Record 42 of Set 5 | goderich
# Processing Record 43 of Set 5 | cayenne
# Processing Record 44 of Set 5 | powell
# Processing Record 45 of Set 5 | norman&wells
# Processing Record 46 of Set 5 | san&policarpo
# Processing Record 47 of Set 5 | borogontsy
# Processing Record 48 of Set 5 | asau
# Processing Record 49 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 0 of Set 6 | conceicao&do&araguaia
# City not found. Skipping...
# Processing Record 1 of Set 6 | huilong
# Processing Record 2 of Set 6 | sasaram
# Processing Record 3 of Set 6 | tezu
# Processing Record 4 of Set 6 | tenali
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | aksu
# Processing Record 7 of Set 6 | asfi
# Processing Record 8 of Set 6 | alberton
# Processing Record 9 of Set 6 | tecolutilla
# Processing Record 10 of Set 6 | kalmunai
# Processing Record 11 of Set 6 | whitehorse
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | bathsheba
# Processing Record 14 of Set 6 | mangochi
# Processing Record 15 of Set 6 | cherskiy
# Processing Record 16 of Set 6 | tazovskiy
# Processing Record 17 of Set 6 | sile
# Processing Record 18 of Set 6 | mumford
# Processing Record 19 of Set 6 | rajpura
# Processing Record 20 of Set 6 | shimoda
# Processing Record 21 of Set 6 | tuatapere
# Processing Record 22 of Set 6 | jalu
# Processing Record 23 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 24 of Set 6 | shihezi
# Processing Record 25 of Set 6 | puerto&ayora
# Processing Record 26 of Set 6 | kavieng
# Processing Record 27 of Set 6 | teacapan
# Processing Record 28 of Set 6 | san&patricio
# Processing Record 29 of Set 6 | mombetsu
# Processing Record 30 of Set 6 | khonsa
# Processing Record 31 of Set 6 | piopio
# Processing Record 32 of Set 6 | sao&joao&da&barra
# Processing Record 33 of Set 6 | anloga
# Processing Record 34 of Set 6 | yumen
# Processing Record 35 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | manta
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | paramonga
# Processing Record 39 of Set 6 | mabaruma
# Processing Record 40 of Set 6 | qui&nhon
# Processing Record 41 of Set 6 | henties&bay
# City not found. Skipping...
# Processing Record 42 of Set 6 | oistins
# Processing Record 43 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 6 | falmouth
# Processing Record 45 of Set 6 | belushya&guba
# City not found. Skipping...
# Processing Record 46 of Set 6 | tawang
# Processing Record 47 of Set 6 | dingle
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | ahuimanu
# Processing Record 0 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 7 | sikeston
# Processing Record 2 of Set 7 | atar
# Processing Record 3 of Set 7 | srednekolymsk
# Processing Record 4 of Set 7 | meulaboh
# Processing Record 5 of Set 7 | vardo
# Processing Record 6 of Set 7 | yulara
# Processing Record 7 of Set 7 | faanui
# Processing Record 8 of Set 7 | anadyr
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | macapa
# Processing Record 11 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 7 | sardulgarh
# Processing Record 13 of Set 7 | varna
# Processing Record 14 of Set 7 | port&blair
# Processing Record 15 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 7 | mys&shmidta
# Processing Record 17 of Set 7 | saldanha
# Processing Record 18 of Set 7 | boddam
# Processing Record 19 of Set 7 | bouloupari
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | xinyu
# Processing Record 22 of Set 7 | turochak
# Processing Record 23 of Set 7 | alice&springs
# Processing Record 24 of Set 7 | santa&helena&de&goias
# Processing Record 25 of Set 7 | vilyuysk
# Processing Record 26 of Set 7 | abu&samrah
# Processing Record 27 of Set 7 | sakaiminato
# Processing Record 28 of Set 7 | mecca
# Processing Record 29 of Set 7 | abu&kamal
# Processing Record 30 of Set 7 | praia
# Processing Record 31 of Set 7 | naze
# Processing Record 32 of Set 7 | narsaq
# Processing Record 33 of Set 7 | puerto&cabezas
# Processing Record 34 of Set 7 | buchen
# Processing Record 35 of Set 7 | bengkulu
# Processing Record 36 of Set 7 | illela
# Processing Record 37 of Set 7 | vigrestad
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | acari
# Processing Record 40 of Set 7 | vysotskoye
# Processing Record 41 of Set 7 | umba
# Processing Record 42 of Set 7 | fontenay-le-comte
# Processing Record 43 of Set 7 | vernon
# Processing Record 44 of Set 7 | beidao
# Processing Record 45 of Set 7 | port&shepstone
# Processing Record 46 of Set 7 | zharkent
# Processing Record 47 of Set 7 | luderitz
# Processing Record 48 of Set 7 | bauchi
# Processing Record 49 of Set 7 | lagos
# Processing Record 0 of Set 8 | green&river
# Processing Record 1 of Set 8 | caravelas
# Processing Record 2 of Set 8 | esil
# Processing Record 3 of Set 8 | tahta
# Processing Record 4 of Set 8 | ballina
# Processing Record 5 of Set 8 | boca&do&acre
# Processing Record 6 of Set 8 | kudahuvadhoo
# Processing Record 7 of Set 8 | constitucion
# Processing Record 8 of Set 8 | zhangjiakou
# Processing Record 9 of Set 8 | naruja
# Processing Record 10 of Set 8 | nileshwar
# Processing Record 11 of Set 8 | pontianak
# Processing Record 12 of Set 8 | abha
# Processing Record 13 of Set 8 | lamar
# Processing Record 14 of Set 8 | dickinson
# Processing Record 15 of Set 8 | cockburn&town
# Processing Record 16 of Set 8 | hithadhoo
# Processing Record 17 of Set 8 | mazamari
# Processing Record 18 of Set 8 | merauke
# Processing Record 19 of Set 8 | montrose
# Processing Record 20 of Set 8 | riachao
# Processing Record 21 of Set 8 | kaeo
# Processing Record 22 of Set 8 | buchlovice
# Processing Record 23 of Set 8 | talnakh
# Processing Record 24 of Set 8 | coquimbo
# Processing Record 25 of Set 8 | shache
# Processing Record 26 of Set 8 | mlowo
# Processing Record 27 of Set 8 | nacala
# Processing Record 28 of Set 8 | ulladulla
# Processing Record 29 of Set 8 | kragujevac
# Processing Record 30 of Set 8 | orlik
# Processing Record 31 of Set 8 | ostashkov
# Processing Record 32 of Set 8 | catarman
# Processing Record 33 of Set 8 | bara
# Processing Record 34 of Set 8 | sola
# Processing Record 35 of Set 8 | nouadhibou
# Processing Record 36 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 38 of Set 8 | russell
# Processing Record 39 of Set 8 | beruni
# City not found. Skipping...
# Processing Record 40 of Set 8 | atasu
# Processing Record 41 of Set 8 | rio&gallegos
# Processing Record 42 of Set 8 | balakhta
# Processing Record 43 of Set 8 | salinopolis
# Processing Record 44 of Set 8 | batavia
# Processing Record 45 of Set 8 | jumla
# Processing Record 46 of Set 8 | clyde&river
# Processing Record 47 of Set 8 | phangnga
# Processing Record 48 of Set 8 | port&hardy
# Processing Record 49 of Set 8 | malanje
# Processing Record 0 of Set 9 | halacho
# Processing Record 1 of Set 9 | sao&filipe
# Processing Record 2 of Set 9 | wamba
# Processing Record 3 of Set 9 | yakeshi
# Processing Record 4 of Set 9 | iracoubo
# Processing Record 5 of Set 9 | ust-kuyga
# Processing Record 6 of Set 9 | milos
# Processing Record 7 of Set 9 | saint-pierre
# Processing Record 8 of Set 9 | tarbagatay
# Processing Record 9 of Set 9 | antofagasta
# Processing Record 10 of Set 9 | belle&fourche
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | delmas
# Processing Record 13 of Set 9 | dudinka
# Processing Record 14 of Set 9 | camopi
# Processing Record 15 of Set 9 | klyuchi
# Processing Record 16 of Set 9 | salalah
# Processing Record 17 of Set 9 | cap&malheureux
# Processing Record 18 of Set 9 | sobolevo
# Processing Record 19 of Set 9 | saint-louis
# Processing Record 20 of Set 9 | alyangula
# Processing Record 21 of Set 9 | karratha
# Processing Record 22 of Set 9 | glen&allen
# Processing Record 23 of Set 9 | telimele
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | richards&bay
# Processing Record 26 of Set 9 | sao&francisco&do&sul
# Processing Record 27 of Set 9 | ilulissat
# Processing Record 28 of Set 9 | correntina
# Processing Record 29 of Set 9 | bilma
# Processing Record 30 of Set 9 | lompoc
# Processing Record 31 of Set 9 | shitkino
# Processing Record 32 of Set 9 | hervey&bay
# Processing Record 33 of Set 9 | severo-kurilsk
# Processing Record 34 of Set 9 | vanderhoof
# Processing Record 35 of Set 9 | wilmington&island
# Processing Record 36 of Set 9 | bishop&auckland
# Processing Record 37 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 9 | medea
# Processing Record 39 of Set 9 | sakakah
# Processing Record 40 of Set 9 | faya
# Processing Record 41 of Set 9 | saint-joseph
# Processing Record 42 of Set 9 | lakes&entrance
# Processing Record 43 of Set 9 | zhigansk
# Processing Record 44 of Set 9 | bereda
# Processing Record 45 of Set 9 | havre-saint-pierre
# Processing Record 46 of Set 9 | vicuna
# Processing Record 47 of Set 9 | aksarka
# Processing Record 48 of Set 9 | tessalit
# Processing Record 49 of Set 9 | danane
# Processing Record 0 of Set 10 | soyo
# Processing Record 1 of Set 10 | okhotsk
# Processing Record 2 of Set 10 | semypolky
# Processing Record 3 of Set 10 | manama
# Processing Record 4 of Set 10 | mpika
# Processing Record 5 of Set 10 | felipe&carrillo&puerto
# Processing Record 6 of Set 10 | sibolga
# Processing Record 7 of Set 10 | makakilo&city
# Processing Record 8 of Set 10 | guarapari
# Processing Record 9 of Set 10 | la&quinta
# City not found. Skipping...
# Processing Record 10 of Set 10 | santa&isabel&do&rio&negro
# Processing Record 11 of Set 10 | liverpool
# Processing Record 12 of Set 10 | san&jose&de&rio&tinto
# Processing Record 13 of Set 10 | koutsouras
# Processing Record 14 of Set 10 | adrar
# Processing Record 15 of Set 10 | honiara
# Processing Record 16 of Set 10 | garden&city
# Processing Record 17 of Set 10 | roald
# Processing Record 18 of Set 10 | norden
# Processing Record 19 of Set 10 | boden
# Processing Record 20 of Set 10 | nicoya
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | kampong&chhnang
# City not found. Skipping...
# Processing Record 23 of Set 10 | nyurba
# Processing Record 24 of Set 10 | dera&bugti
# Processing Record 25 of Set 10 | ahipara
# Processing Record 26 of Set 10 | dawei
# Processing Record 27 of Set 10 | klaksvik
# Processing Record 28 of Set 10 | tilichiki
# Processing Record 29 of Set 10 | gorontalo
# Processing Record 30 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 10 | cuajinicuilapa
# Processing Record 32 of Set 10 | kampot
# Processing Record 33 of Set 10 | marawi
# Processing Record 34 of Set 10 | mount&isa
# Processing Record 35 of Set 10 | port-gentil
# Processing Record 36 of Set 10 | ust-maya
# Processing Record 37 of Set 10 | turayf
# Processing Record 38 of Set 10 | mantenopolis
# Processing Record 39 of Set 10 | hokitika
# Processing Record 40 of Set 10 | batagay-alyta
# Processing Record 41 of Set 10 | aklavik
# Processing Record 42 of Set 10 | kapuskasing
# Processing Record 43 of Set 10 | fort&nelson
# Processing Record 44 of Set 10 | rincon
# Processing Record 45 of Set 10 | dvinskoy
# Processing Record 46 of Set 10 | sorland
# Processing Record 47 of Set 10 | santo&antonio&do&amparo
# Processing Record 48 of Set 10 | chapais
# Processing Record 49 of Set 10 | san&fernando
# Processing Record 0 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 11 | fundacion
# Processing Record 2 of Set 11 | kahului
# Processing Record 3 of Set 11 | honningsvag
# Processing Record 4 of Set 11 | bur&gabo
# Processing Record 5 of Set 11 | sadiqabad
# Processing Record 6 of Set 11 | usinsk
# Processing Record 7 of Set 11 | dembi&dolo
# City not found. Skipping...
# Processing Record 8 of Set 11 | drumheller
# Processing Record 9 of Set 11 | belmonte
# Processing Record 10 of Set 11 | angoche
# Processing Record 11 of Set 11 | moranbah
# Processing Record 12 of Set 11 | gat
# Processing Record 13 of Set 11 | malakal
# Processing Record 14 of Set 11 | goure
# Processing Record 15 of Set 11 | north&bend
# Processing Record 16 of Set 11 | panshi
# Processing Record 17 of Set 11 | kununurra
# Processing Record 18 of Set 11 | sinazongwe
# Processing Record 19 of Set 11 | sao&felix&do&xingu
# Processing Record 20 of Set 11 | los&llanos&de&aridane
# City not found. Skipping...
# Processing Record 21 of Set 11 | lokosovo
# Processing Record 22 of Set 11 | shangrao
# Processing Record 23 of Set 11 | coracao&de&jesus
# City not found. Skipping...
# Processing Record 24 of Set 11 | la&ronge
# City not found. Skipping...
# Processing Record 25 of Set 11 | youghal
# Processing Record 26 of Set 11 | brody
# Processing Record 27 of Set 11 | chifeng
# Processing Record 28 of Set 11 | port&elizabeth
# Processing Record 29 of Set 11 | lithakia
# Processing Record 30 of Set 11 | wattegama
# Processing Record 31 of Set 11 | labytnangi
# Processing Record 32 of Set 11 | havoysund
# Processing Record 33 of Set 11 | hirara
# Processing Record 34 of Set 11 | ulverstone
# Processing Record 35 of Set 11 | mayang&imphal
# Processing Record 36 of Set 11 | baykit
# Processing Record 37 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 11 | alofi
# Processing Record 39 of Set 11 | mahibadhoo
# Processing Record 40 of Set 11 | raga
# Processing Record 41 of Set 11 | upernavik
# Processing Record 42 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 11 | wenling
# Processing Record 44 of Set 11 | alugan
# Processing Record 45 of Set 11 | jatiroto
# Processing Record 46 of Set 11 | wlodawa
# Processing Record 47 of Set 11 | palmer
# Processing Record 48 of Set 11 | katsuura
# Processing Record 49 of Set 11 | svetlogorsk
# Processing Record 0 of Set 12 | jacareacanga
# Processing Record 1 of Set 12 | pantai&remis
# Processing Record 2 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 12 | chake&chake
# Processing Record 4 of Set 12 | tutoia
# Processing Record 5 of Set 12 | torrelavega
# Processing Record 6 of Set 12 | jiazi
# Processing Record 7 of Set 12 | wanning
# Processing Record 8 of Set 12 | matagami
# Processing Record 9 of Set 12 | coihaique
# Processing Record 10 of Set 12 | pagudpud
# Processing Record 11 of Set 12 | churhat
# Processing Record 12 of Set 12 | soe
# Processing Record 13 of Set 12 | poshekhonye
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | menongue
# Processing Record 16 of Set 12 | xinqing
# Processing Record 17 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 12 | arman
# Processing Record 19 of Set 12 | bambui
# Processing Record 20 of Set 12 | locri
# Processing Record 21 of Set 12 | montalvo
# Processing Record 22 of Set 12 | udachnyy
# Processing Record 23 of Set 12 | chichi
# Processing Record 24 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 12 | guerrero&negro
# Processing Record 26 of Set 12 | sundargarh
# Processing Record 27 of Set 12 | karpogory
# Processing Record 28 of Set 12 | artyom
# Processing Record 29 of Set 12 | luanda
# Processing Record 30 of Set 12 | baie-comeau
# Processing Record 31 of Set 12 | port&lincoln
# Processing Record 32 of Set 12 | ocampo
# Processing Record 33 of Set 12 | longuenesse
# Processing Record 34 of Set 12 | baherden
# Processing Record 35 of Set 12 | subottsi
# Processing Record 36 of Set 12 | caucaia
# Processing Record 37 of Set 12 | pandan
# Processing Record 38 of Set 12 | fethiye
# Processing Record 39 of Set 12 | laurel
# Processing Record 40 of Set 12 | grafton
# Processing Record 41 of Set 12 | yarensk
# Processing Record 42 of Set 12 | vaovai
# City not found. Skipping...
# Processing Record 43 of Set 12 | syamzha
# Processing Record 44 of Set 12 | nizhniy&kuranakh
# Processing Record 45 of Set 12 | rocha
# Processing Record 46 of Set 12 | storforshei
# Processing Record 47 of Set 12 | wainwright
# Processing Record 48 of Set 12 | sinnamary
# Processing Record 49 of Set 12 | fayaoue
# Processing Record 0 of Set 13 | bundaberg
# Processing Record 1 of Set 13 | micheweni
# Processing Record 2 of Set 13 | buchanan
# Processing Record 3 of Set 13 | koregaon
# Processing Record 4 of Set 13 | severo-yeniseyskiy
# Processing Record 5 of Set 13 | sangueya
# Processing Record 6 of Set 13 | muhos
# Processing Record 7 of Set 13 | niagara&falls
# Processing Record 8 of Set 13 | tampin
# Processing Record 9 of Set 13 | boquim
# Processing Record 10 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 11 of Set 13 | terre&haute
# City not found. Skipping...
# Processing Record 12 of Set 13 | huarmey
# Processing Record 13 of Set 13 | stornoway
# Processing Record 14 of Set 13 | kolyvan
# Processing Record 15 of Set 13 | santa&cruz&cabralia
# Processing Record 16 of Set 13 | kerema
# Processing Record 17 of Set 13 | mortka
# Processing Record 18 of Set 13 | vanavara
# Processing Record 19 of Set 13 | kousseri
# Processing Record 20 of Set 13 | barkly&west
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Sort dataframe and correct formatting
city_data_df.sort_values(['City'], ascending=True, inplace=True)
city_data_df.reset_index(drop=True, inplace=True)
city_data_df['City'] = city_data_df['City'].str.replace('&', ' ')

# Display sample data
city_data_df.head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      abalak  58.1286  68.5944    -18.32        99         100        1.53
# 1        abha  18.2164  42.5053     12.14        82           0        6.17
# 2   abu dhabi  24.6000  72.7000     10.97        57           0        1.54
# 3   abu kamal  24.6000  72.7000     10.97        57           0        1.54
# 4  abu samrah  24.6000  72.7000     10.97        57           0        1.54
#
#   Country        Date
# 0      RU  1675727123
# 1      SA  1675727201
# 2      IN  1675727092
# 3      IN  1675727092
# 4      IN  1675727185

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            abalak  58.1286  68.5944    -18.32        99         100
# 1              abha  18.2164  42.5053     12.14        82           0
# 2         abu dhabi  24.6000  72.7000     10.97        57           0
# 3         abu kamal  24.6000  72.7000     10.97        57           0
# 4        abu samrah  24.6000  72.7000     10.97        57           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.53      RU  1675727123
# 1              6.17      SA  1675727201
# 2              1.54      IN  1675727092
# 3              1.54      IN  1675727092
# 4              1.54      IN  1675727185

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

fig1 = city_data_df.plot(x='Lat', y='Max Temp',
                         kind='scatter', 
                         xlabel='Latitude',
                         ylabel='Max Temperature (C)',
                         title=' City Latitude vs. Temperature (2023-02-03)',
                         figsize = (9,7),
                         s=80,
                         c='#287cb7',
                         edgecolor = 'black',
                         alpha=0.85,
                         grid=True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
fig2 = city_data_df.plot(x='Lat', y='Humidity',
                         kind='scatter', 
                         xlabel='Latitude',
                         ylabel='Humidity (%)',
                         title=' City Latitude vs. Humidity (2023-02-03)',
                         figsize = (9,7),
                         s=80,
                         c='#287cb7',
                         edgecolor = 'black',
                         alpha=0.85,
                         grid=True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
fig3 = city_data_df.plot(x='Lat', y='Cloudiness',
                         kind='scatter', 
                         xlabel='Latitude',
                         ylabel='Cloudiness (%)',
                         title=' City Latitude vs. Cloudiness (2023-02-03)',
                         figsize = (9,7),
                         s=80,
                         c='#287cb7',
                         edgecolor = 'black',
                         alpha=0.85,
                         grid=True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
fig4 = city_data_df.plot(x='Lat', y='Wind Speed',
                         kind='scatter', 
                         xlabel='Latitude',
                         ylabel='Wind Speed (m/s)',
                         title=' City Latitude vs. Wind Speed (2023-02-03)',
                         figsize = (9,7),
                         s=80,
                         c='#287cb7',
                         edgecolor = 'black',
                         alpha=0.85,
                         grid=True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg(x,y):
    
    # Linear regression setup
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    regress_values = (slope*x) + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Incoporate graph properties
    plt.figure(figsize=(9,7))
    plt.xlabel('Latitude')
    plt.ylabel(y.name)
    
    # Plotting scatter and linear regression
    plt.scatter(x, y, c='#287cb7', s=90, edgecolor='black', alpha=0.75)
    plt.plot(x, regress_values, 'r-')
    
    # Annotate linear regression line
    plt.annotate(line_eq, xy=(min(x), min(regress_values)+5), c='r', fontsize=20)
    
    # Print r value
    print(f"The r-value is: {rvalue}")
    
    return plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >=0].sort_values(['City'], ascending=True)

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            abalak  58.1286  68.5944    -18.32        99         100
# 1              abha  18.2164  42.5053     12.14        82           0
# 2         abu dhabi  24.6000  72.7000     10.97        57           0
# 3         abu kamal  24.6000  72.7000     10.97        57           0
# 4        abu samrah  24.6000  72.7000     10.97        57           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.53      RU  1675727123
# 1              6.17      SA  1675727201
# 2              1.54      IN  1675727092
# 3              1.54      IN  1675727092
# 4              1.54      IN  1675727185

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0].sort_values(['City'], ascending=True)

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5            acari -15.4311  -74.6158     24.71        87          84
# 7          ahipara -35.1667  173.1667     22.10        58          18
# 9            airai  -8.9266  125.4092     19.58        76          74
# 17           alofi -19.0595 -169.9187     29.94        70          40
# 19       alyangula -13.8483  136.4192     29.62        58          65
#
#          Wind Speed Country        Date
# City_ID
# 5              2.72      PE  1675727193
# 7              3.78      NZ  1675727252
# 9              1.27      TL  1675727127
# 17             3.60      NU  1675727275
# 19             0.83      AU  1675727222

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
# Out:
# The r-value is: -0.8552905740462409

# %%
# Linear regression on Southern Hemisphere
lin_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
# Out:
# The r-value is: 0.4129749250655596

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model is attempting fit a line to the data points in the scatter plot, based on the relationship between the temperature and latitude in the northern and southern hemisphere. The results from the northern hemisphere suggests a strong negative relationship between latitude and maximum temperature. The results from the southern hemisphere suggests a moderate positive relationship between the two variables. Both results make logical sense as temperatures generally decrease as you move away from the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
# Out:
# The r-value is: 0.43394107638670476

# %%
# Southern Hemisphere
lin_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
# Out:
# The r-value is: 0.45422068978423946

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model is attempting fit a line to the data points in the scatter plot, based on the relationship between the humidity and latitude in the northern and southern hemisphere. The results from both the northern and sourthern hemisphere suggests a moderate positive relationship between latitude and maximum temperature. as latitude increases, humidity increases. A quick google search suggests that humidity is not directly proportional to distance from the equator, and are dependent on a variety of factors, most prominently how close to the sea a city is. Given the moderate strength of the correlation coefficient, this linear regression model may not be a strong predictor of humidity based on latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
# Out:
# The r-value is: 0.23935039191902238

# %%
# Southern Hemisphere
lin_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
# Out:
# The r-value is: 0.4378041047127225

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model is attempting fit a line to the data points in the scatter plot, based on the relationship between the cloudiness and latitude in the northern and southern hemisphere. The results from the northern indicates a weak, positive linear relationship between latitude and cloudiness. This means that as latitude increases, cloudiness tends to increase slightly, but the relationship is not very strong. Based on a google search, there is a general trend of decreasing cloudiness as you move away from the equator and towards the poles. This relationship can be described by the moderate positive correlation in the southern hemisphere result. With both graphs, as there are many outliers, this linear regression model may not be a good predictor of cloudiness based on latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
# Out:
# The r-value is: 0.08000633075119518

# %%
# Southern Hemisphere
lin_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
# Out:
# The r-value is: -0.39125241327838717

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model is attempting fit a line to the data points in the scatter plot, based on the relationship between wind speed and latitude in the northern and southern hemisphere. The results from both analysis suggest very weak correlation between the two variables as calculated by the almost negligible r-value. combined with the fact that many outliers exist on both plots, this linear regression should not be used to forecast wind speed based on latitude.
